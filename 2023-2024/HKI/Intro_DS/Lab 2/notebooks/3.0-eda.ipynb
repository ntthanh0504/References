# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import seaborn as sns

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
cleaned_df = pd.read_csv("../data/processed/21127166_africa_processed.csv")

# %%
# TEST
cleaned_df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0        44903225.0         22040988.0       22862237.0   35.194972
# 1        44177969.0         21680725.0       22497244.0   21.524000
# 2        43451666.0         21318767.0       22132899.0   22.431000
# 3        42705368.0         20948465.0       21756903.0   23.298000
# 4        41927007.0         20564404.0       21362603.0   24.074000
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0   10.552561                   8.212828                   13.74374
# 1    4.546000                  10.000000                   31.03555
# 2    5.398000                  10.000000                   30.49272
# 3    4.392000                  10.000000                   30.46512
# 4    4.482000                  10.000000                   30.68305
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                     48.164092                            49.723269
# 1                     10.323790                             3.929019
# 2                     10.524500                             3.867479
# 3                      9.940742                             3.754027
# 4                     10.007310                             3.807302
#
#    Female Employment in Industry(%)  ...  \
# 0                         10.118534  ...
# 1                         23.940450  ...
# 2                         24.429170  ...
# 3                         23.812240  ...
# 4                         24.043400  ...
#
#    Electric Power Consumption(kWH per capita)  \
# 0                                  712.608182
# 1                                  712.608182
# 2                                  712.608182
# 3                                  712.608182
# 4                                  712.608182
#
#    Renewable Energy Consumption (%)  Fossil Fuel Consumption (%)  \
# 0                         60.381415                    41.345309
# 1                         60.381415                    41.345309
# 2                          0.150000                    41.345309
# 3                          0.160000                    41.345309
# 4                          0.190000                    41.345309
#
#    Male life expectancy  Female life expectancy   School enrollment, primary  \
# 0             57.057657                60.885628                   97.409735
# 1             74.879000                77.959000                   97.409735
# 2             73.082000                75.912000                  111.281151
# 3             75.238000                77.760000                  108.845848
# 4             74.966000                77.205000                  109.882820
#
#    School enrollment, tertiary  Primary completion rate  Year  Country
# 0                    10.196134                67.268794  2022  Algeria
# 1                    53.741741                67.268794  2021  Algeria
# 2                    52.498619               103.663528  2020  Algeria
# 3                    52.619942               101.364632  2019  Algeria
# 4                    51.365669               105.143959  2018  Algeria
#
# [5 rows x 25 columns]

# %%
# TEST
cleaned_df.shape
# Out:
# (1428, 25)

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')

# YOUR CODE HERE
df_copy.describe()
# Out:
#        Total Population  Female Population  Male Population   Birth Rate  \
# count      1.428000e+03       1.428000e+03     1.428000e+03  1428.000000
# mean       1.858922e+07       9.318571e+06     9.270651e+06    35.194972
# std        2.822195e+07       1.403349e+07     1.419149e+07     8.671475
# min        7.530400e+04       3.767700e+04     3.762700e+04    10.100000
# 25%        2.196516e+06       1.111937e+06     1.084358e+06    30.075000
# 50%        1.000007e+07       5.024364e+06     4.942766e+06    36.442500
# 75%        2.247619e+07       1.119736e+07     1.117145e+07    41.515750
# max        2.185412e+08       1.080931e+08     1.104481e+08    54.068000
#
#         Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# count  1428.000000                1428.000000                1428.000000
# mean     10.552561                   8.212828                  13.743740
# std       3.733395                   1.541391                   7.674594
# min       4.187000                   4.000000                   2.195539
# 25%       7.705250                   7.000000                   7.575027
# 50%       9.987000                   8.212828                  12.826850
# 75%      12.932500                   9.000000                  18.248188
# max      21.967000                  12.000000                  39.834960
#
#        Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# count                   1428.000000                          1428.000000
# mean                      48.164092                            49.723269
# std                       21.623268                            24.430893
# min                        1.184986                             0.913054
# 25%                       32.196838                            29.076730
# 50%                       48.164092                            49.723269
# 75%                       66.358423                            70.288610
# max                       92.591690                            96.987240
#
#        Female Employment in Industry(%)  ...  Net income from Abroad  \
# count                       1428.000000  ...            1.428000e+03
# mean                          10.118534  ...           -1.116459e+09
# std                            8.170177  ...            2.676998e+09
# min                            0.206030  ...           -2.577629e+10
# 25%                            3.919370  ...           -1.034244e+09
# 50%                            8.354249  ...           -1.627279e+08
# 75%                           13.668938  ...           -1.655021e+07
# max                           43.624750  ...            1.829770e+09
#
#        Agriculture value added(in USD)  \
# count                     1.428000e+03
# mean                      4.975832e+09
# std                       1.154672e+10
# min                       7.907084e+06
# 25%                       4.724690e+08
# 50%                       1.710940e+09
# 75%                       4.975832e+09
# max                       1.147808e+11
#
#        Electric Power Consumption(kWH per capita)  \
# count                                 1428.000000
# mean                                   712.608182
# std                                    600.845348
# min                                     22.481844
# 25%                                    712.608182
# 50%                                    712.608182
# 75%                                    712.608182
# max                                   4766.652371
#
#        Renewable Energy Consumption (%)  Fossil Fuel Consumption (%)  \
# count                       1428.000000                  1428.000000
# mean                          60.381415                    41.345309
# std                           29.219282                    20.449108
# min                            0.060000                     0.000000
# 25%                           38.997500                    41.345309
# 50%                           70.120000                    41.345309
# 75%                           84.575000                    41.345309
# max                           96.730000                    99.977917
#
#        Male life expectancy  Female life expectancy   \
# count           1428.000000              1428.000000
# mean              57.057657                60.885628
# std                7.466853                 8.287832
# min               35.825000                41.756000
# 25%               51.879750                55.093500
# 50%               57.057657                60.841500
# 75%               61.488500                65.673750
# max               75.238000                82.000000
#
#        School enrollment, primary  School enrollment, tertiary  \
# count                 1428.000000                  1428.000000
# mean                    97.409735                    10.196134
# std                     21.141805                     7.920336
# min                      9.062259                     0.219890
# 25%                     88.893934                     5.575843
# 50%                     97.409735                    10.196134
# 75%                    108.182938                    10.196134
# max                    156.445053                    60.497360
#
#        Primary completion rate
# count              1428.000000
# mean                 67.268794
# std                  18.243949
# min                  13.453430
# 25%                  61.660519
# 50%                  67.268794
# 75%                  71.681953
# max                 115.184677
#
# [8 rows x 23 columns]

# %% [markdown]
# **TODO**: Give your obervation here
#
# Use basic function of Pandas - `describe()` to show some basic descriptive statistics information:
# - The mean
# - Standare error (of the sample mean)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# create a copy
df_copy = cleaned_df.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is large.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
#  create a copy dataframe
df_copy = cleaned_df.copy()

# exclude top 10 countries with the highest population
top_10_countries = df_copy.groupby('Country').mean('Total Population').sort_values(by='Total Population', ascending=False).reset_index().head(10)
# Exclude the categorical features from the matrix
top_10_countries.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(top_10_countries.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **YOUR ANSWER**
#
# Correlation between attributes in the 10 countries with the largest populations increased significantly in either a positive or negative direction compared to the correlation between attributes in all countries. The most notable example is that the attribute National Income per Capita has a relatively high correlation with other attributes.

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
#  create a copy dataframe
df_copy = cleaned_df.copy()

# exclude top 10 countries with the smallest population
top_10_countries = df_copy.groupby('Country').mean('Total Population').sort_values(by='Total Population', ascending=True).reset_index().head(10)

# Exclude the categorical features from the matrix
top_10_countries.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(top_10_countries.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **YOUR ANSWER**
#
# The correlation between attributes in the 10 countries with the lowest populations is slightly weaker or slightly stronger than the correlation between attributes in all countries. However, National Income per Capita is still strongly correlated with other attributes.

# %% [markdown]
# #### Is that possible to drop any features that have less effect?

# %% [markdown]
# We observed that total population, female population, and male population are highly correlated. This means that they tend to change together. Therefore, we can use only one of these attributes to represent all three, without losing significant information. We choose to use total population, as it is the most comprehensive measure of population size.

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# Create a new dataframe
avg_birthrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_birthrate_df["Avg.Birth Rate"] = cleaned_df.groupby("Country")["Birth Rate"].mean()

# Set the index as a column - countries
avg_birthrate_df["Country"] = avg_birthrate_df.index

# Drop the index
avg_birthrate_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_birthrate_df.sort_values("Avg.Birth Rate", inplace=True, ascending=False)

# Display
avg_birthrate_df.head()
# Out:
#     Avg.Birth Rate  Country
# 35       48.968178    Niger
# 9        48.202035     Chad
# 42       47.423535  Somalia
# 29       45.323213     Mali
# 1        44.538892   Angola

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_birthrate_df.head(), x="Country", y= "Avg.Birth Rate")

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_deathrate_df ["Avg.Death Rate"] = cleaned_df.groupby("Country")["Death Rate"].mean()

# Set the index as a column - countries
avg_deathrate_df["Country"] = avg_deathrate_df .index

# Drop the index
avg_deathrate_df .reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_deathrate_df .sort_values("Avg.Death Rate", inplace=True, ascending=False)

# Display
avg_deathrate_df .head()
# Out:
#     Avg.Death Rate                   Country
# 24       16.079520                   Lesotho
# 9        15.596270                      Chad
# 36       15.292520                   Nigeria
# 41       14.848270              Sierra Leone
# 8        14.567449  Central African Republic

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_deathrate_df.head(), x="Country", y= "Avg.Death Rate")

# %% [markdown]
# Step 03: My observations and thoughts

# %% [markdown]
# - Niger has the highest number of births per person on average.
# - Lesotho has the highest number of deaths per person on average.
# - Chad has the second-highest number of births and deaths per person on average in Africa.

# %% [markdown]
# ## Making your own question 01? (1.5 points)

# %% [markdown]
# **A possible question is:** What is the relationship between renewable energy consumption and GDP per capita?
#
# **Answering this question will** help us to
# - Understand the relationship between economic development and environmental sustainability.
# - Identify countries that are leading the way in adopting renewable energy, and those that are lagging behind.
# - Generate insights into how to promote renewable energy adoption in countries with low GDP per capita.
#
# **How we answer this question:** We will compare the average renewable energy consumption and GDP in USD for the largest countries in the world, while controlling for other factors that may influence the relationship, such as population size.

# %% [markdown]
# ### Pre-processing

# %%
import statsmodels.api as sm

# %%
def get_data(df: pd.DataFrame, selected_columns: list) -> pd.DataFrame:
    """Returns a DataFrame containing the selected columns from the input DataFrame."""
    return df[selected_columns]

def group_by(df: pd.DataFrame, key: str, columns: list, method: str) -> pd.DataFrame:
    """Returns a DataFrame grouped by the specified key and aggregated using the specified method."""
    return df.groupby(key)[columns].agg(method).reset_index().\
        sort_values(by=columns, ascending=False).reset_index(drop=True).\
        rename(columns={column: f'Avg.{column}' for column in columns})

def plot_top_values(df: pd.DataFrame, x: str, y: str, top_n: int, ax: plt.Axes = None) -> None:
    """Plots a bar chart of the top `top_n` values in the specified column `y` of the input DataFrame, grouped by the specified column `x`.

    Args:
        df: The DataFrame to plot.
        x: The column to group by.
        y: The column to plot.
        top_n: The number of top values to plot.
        ax: The optional Axes object to plot on.
    """

    colors = ['grey'] * len(df)
    colors[df[x].idxmax()] = 'red'

    sns.barplot(x=x, y=y, data=df.head(top_n), palette=colors, ax=ax)

# %%
# set data to be used
selected_columns = ['Country', 'Renewable Energy Consumption (%)', 'GDP in USD', 'Total Population']
df_copy = cleaned_df.copy()
data = df_copy[selected_columns]
data.head()
# Out:
#    Country  Renewable Energy Consumption (%)    GDP in USD  Total Population
# 0  Algeria                         60.381415  1.919129e+11        44903225.0
# 1  Algeria                         60.381415  1.634722e+11        44177969.0
# 2  Algeria                          0.150000  1.457437e+11        43451666.0
# 3  Algeria                          0.160000  1.717603e+11        42705368.0
# 4  Algeria                          0.190000  1.749109e+11        41927007.0

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: Comparing the average renewable energy consumption and GDP in USD for the largest countries in the world

# %%
# exclude mean of renewable energy consumption and gdp in usd in each country
avg_consumption_by_country  = group_by(data, key='Country', columns=['Renewable Energy Consumption (%)'], method='mean')
avg_gdp_by_country = group_by(data, key='Country', columns=['GDP in USD'], method='mean')

print("Average of renewable energy consumption in each country")
print(avg_consumption_by_country.head())
print("\nAverage of GDP in each country")
print(avg_gdp_by_country.head())
# Out:
# Average of renewable energy consumption in each country
#                     Country  Avg.Renewable Energy Consumption (%)
# 0                    Uganda                             92.489693
# 1                   Somalia                             92.357193
# 2                  Ethiopia                             91.086172
# 3                   Burundi                             90.849693
# 4  Central African Republic                             90.490765
#
# Average of GDP in each country
#             Country  Avg.GDP in USD
# 0      South Africa    2.981508e+11
# 1           Nigeria    2.831895e+11
# 2  Egypt, Arab Rep.    2.002404e+11
# 3           Algeria    1.269419e+11
# 4           Morocco    8.767048e+10

# %%
# Plot the top 5 countries with the highest renewable energy consumption
fig, ax = plt.subplots(1, 2, figsize=(20, 8))

ax[0].set_title('Avg. Renewable Energy Consumption', fontsize=18, fontweight='bold', pad=30)
ax[0].set_xlabel('Avg. Renewable Energy Consumption (%)', fontsize=16, labelpad=20)
ax[0].set_ylabel('Country', fontsize=16, labelpad=20)

plot_top_values(avg_consumption_by_country, x='Avg.Renewable Energy Consumption (%)', y='Country', top_n=5, ax=ax[0])

# Plot the top 5 countries with the highest GDP
ax[1].set_title('Avg. GDP in USD', fontsize=18, fontweight='bold', pad=30)
ax[1].set_xlabel('Avg. GDP in USD', fontsize=16, labelpad=20)
ax[1].set_ylabel('Country', fontsize=16, labelpad=20)

plot_top_values(avg_gdp_by_country, x='Avg.GDP in USD', y='Country', top_n=5, ax=ax[1])

# Add a suptitle to the figure
plt.suptitle('Top 5 countries with the highest feature', fontsize=20, fontweight='bold', y=1.05)

# Tighten the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Step 02: Estimate correlation between renewable energy consumption and GDP in USD, while controllingpopulation size.

# %%
# Compute the standardized GDP in USD
gdp_std = (data['GDP in USD'] - data['GDP in USD'].mean()) / data['GDP in USD'].std()
total_population_std = (data['Total Population'] - data['Total Population'].mean()) / data['Total Population'].std()
# Create a new DataFrame with standardized GDP in USD and other features
data_std = pd.DataFrame({
    'Renewable Energy Consumption (%)': data['Renewable Energy Consumption (%)'],
    'GDP in USD (std)': gdp_std,
    'Total Population (std)': total_population_std
})

# Compute the correlation matrix
corr_matrix = data_std[['GDP in USD (std)', 'Renewable Energy Consumption (%)']].corr()

# Plot a scatter plot and correlation matrix
fig, ax = plt.subplots(1, 2, figsize=(18,6))

sns.scatterplot(data=data_std, x='GDP in USD (std)', y='Renewable Energy Consumption (%)', ax=ax[0])
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', ax=ax[1])

# Set the titles and labels of the plots
plt.suptitle('Renewable Energy Consumption vs. GDP per capita', fontsize=20, fontweight='bold', y=1.05)
ax[0].set_title('Scatter plot', fontsize=16, fontweight='bold', pad=20)
ax[1].set_title('Correlation Matrix', fontsize=16, fontweight='bold', pad=20)

ax[0].set_xlabel('GDP per capita (USD)', fontsize=16, labelpad=20)
ax[0].set_ylabel('Renewable Energy Consumption (%)', fontsize=16, labelpad=20)

plt.tight_layout()
plt.show()

# %%
# Define the dependent and independent variables
dependent_var = data_std['Renewable Energy Consumption (%)']
independent_vars = data_std[['GDP in USD (std)', 'Total Population (std)']]

# Add a constant term to the independent variables
independent_vars = sm.add_constant(independent_vars)

# Fit the multivariate regression model
model = sm.OLS(dependent_var, independent_vars)
results = model.fit()

# Print the model summary
print(results.summary())
# Out:
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Renewable Energy Consumption (%)   R-squared:                       0.202
# Model:                                          OLS   Adj. R-squared:                  0.201
# Method:                               Least Squares   F-statistic:                     180.4
# Date:                              Tue, 07 Nov 2023   Prob (F-statistic):           1.44e-70
# Time:                                      09:21:45   Log-Likelihood:                -6683.8
# No. Observations:                              1428   AIC:                         1.337e+04
# Df Residuals:                                  1425   BIC:                         1.339e+04
# Df Model:                                         2
# Covariance Type:                          nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     60.3814      0.691     87.358      0.000      59.026      61.737
# GDP in USD (std)         -19.8062      1.051    -18.847      0.000     -21.868     -17.745
# Total Population (std)    16.5554      1.051     15.753      0.000      14.494      18.617
# ==============================================================================
# Omnibus:                       85.952   Durbin-Watson:                   0.122
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               95.637
# Skew:                          -0.612   Prob(JB):                     1.71e-21
# Kurtosis:                       2.672   Cond. No.                         2.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Step 03: My observations and thoughts

# %% [markdown]
# Differences exist between the top 5 countries with the highest average use of renewable energy and the top 5 countries with the highest average GDP in the USA.
#
# There is a negative connection between the consumption of renewable energy and the GDP in the USA, with a correlation of -0.25. In simple terms, when the percentage of energy consumption from renewables goes up, the GDP in the USA tends to go down.
#
# Let's examine the numbers:
#
# - If the GDP in USD (standardized) increases by one unit, the percentage of renewable energy consumption decreases by 19.81 units.
# - If the Total Population (standardized) increases by one unit, the percentage of renewable energy consumption goes up by 16.56 units.
#
# Now, let's look at the P-values for these figures:
#
# - The P-value for Total Population (standardized), GDP in the USA (standardized), and the Intercept is 0.00.
# - All of these P-values are statistically significant, as they are less than 0.05.
#
# Therefore, we can conclude that there is a relationship between Total Population (standardized) and GDP in the USA (standardized) with the percentage of renewable energy consumption.

# %% [markdown]
# ## Making your own question 02? (1.5 points)

# %% [markdown]
# **A positive question is:** What is the current state of unemployment in the countries on the continent?
#
# **Answering this question will help us to:**
# - Determine the magnitude of the unemployment issue in the countries on the continent.
# - Identify the countries that are most likely to experience unemployment.
# - Create targeted policies and programs to address the requirements of different unemployed groups.
#
# **How we will answer this question:** We will examine the following:
# - Average unemployment rate by country and year
# - Difference between employment rates in industry, agriculture, and unemployment rates in the top five countries with the highest average unemployment rates

# %% [markdown]
# ### Pre-processing

# %%
def get_data(df: pd.DataFrame, selected_columns: list) -> pd.DataFrame:
    """Returns a DataFrame containing the selected columns from the input DataFrame."""
    return df[selected_columns]

def group_by(df: pd.DataFrame, key: str, columns: list, method: str,) -> pd.DataFrame:
    """Returns a DataFrame grouped by the specified key and aggregated using the specified method."""
    return df.groupby(key)[columns].agg(method).reset_index().\
        sort_values(by=columns, ascending=False).reset_index(drop=True).\
        rename(columns={column: f'Avg.{column}' for column in columns})
        
def plot_top_values(df: pd.DataFrame, x: str, y: str, top_n: int, ax: plt.Axes = None) -> None:
    """Plots a bar chart of the top `top_n` values in the specified column `y` of the input DataFrame, grouped by the specified column `x`.

    Args:
        df: The DataFrame to plot.
        x: The column to group by.
        y: The column to plot.
        top_n: The number of top values to plot.
        ax: The optional Axes object to plot on.
    """

    colors = ['grey'] * len(df)
    colors[df[x].idxmax()] = 'red'

    sns.barplot(x=x, y=y, data=df.head(top_n), palette=colors, ax=ax)

# %%
df_copy = cleaned_df.copy()
selected_columns = ['Country', 'Year', 'Employment in Industry(%)', 'Employment in Agriculture(%)', 'Unemployment(%)', 'School enrollment, primary', 'School enrollment, tertiary']
data = get_data(df_copy, selected_columns)
data.head()
# Out:
#    Country  Year  Employment in Industry(%)  Employment in Agriculture(%)  \
# 0  Algeria  2022                   13.74374                     48.164092
# 1  Algeria  2021                   31.03555                     10.323790
# 2  Algeria  2020                   30.49272                     10.524500
# 3  Algeria  2019                   30.46512                      9.940742
# 4  Algeria  2018                   30.68305                     10.007310
#
#    Unemployment(%)  School enrollment, primary  School enrollment, tertiary
# 0           11.550                   97.409735                    10.196134
# 1           11.747                   97.409735                    53.741741
# 2           12.248                  111.281151                    52.498619
# 3           10.495                  108.845848                    52.619942
# 4           10.416                  109.882820                    51.365669

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: Average unemployment rate by country and year

# %%
features = ['Employment in Industry(%)', 'Employment in Agriculture(%)', 'Unemployment(%)']
avg_unemployment_by_country = group_by(data, key='Country', columns=features, method='mean').sort_values(by='Avg.Unemployment(%)', ascending=False).reset_index(drop=True)
avg_unemployment_by_year = group_by(data, key='Year', columns=[features[-1]], method='mean')

print("Average employment and unemployment rate by country")
print(avg_unemployment_by_country.head())
print("\nAverage unemployment rate by year")
print(avg_unemployment_by_year.head())
# Out:
# Average employment and unemployment rate by country
#         Country  Avg.Employment in Industry(%)  \
# 0      Djibouti                       5.522972
# 1     Swaziland                      24.365639
# 2  South Africa                      23.529014
# 3       Namibia                      14.562382
# 4   Congo, Rep.                      22.927716
#
#    Avg.Employment in Agriculture(%)  Avg.Unemployment(%)
# 0                          3.564415            27.673964
# 1                         17.588834            24.707179
# 2                         19.415858            22.034071
# 3                         30.387237            21.273714
# 4                         39.143200            20.386393
#
# Average unemployment rate by year
#    Year  Avg.Unemployment(%)
# 0  2020             9.809804
# 1  2021             9.802804
# 2  2022             9.677765
# 3  1995             9.531824
# 4  1996             9.473667

# %%
# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(18, 6))

# Plot the top 5 countries with the highest average unemployment rate
plot_top_values(df=avg_unemployment_by_country, x='Avg.Unemployment(%)', y='Country', top_n=5, ax=ax[0])

# Plot the average unemployment rate by year
sns.lineplot(data=avg_unemployment_by_year.head(10), x='Year', y='Avg.Unemployment(%)', ax=ax[1])

# Set the titles of the subplots
ax[0].set_title('Top 5 countries with the highest average unemployment rate', fontsize=16, fontweight='bold', pad=20)
ax[1].set_title('Average unemployment rate by year', fontsize=16, fontweight='bold', pad=20)

# Adjust the layout of the subplots and display the figure
plt.tight_layout()
plt.show()

# %% [markdown]
# Step 02: Difference between employment rates in industry, agriculture, and unemployment rates in the top five countries with the highest average unemployment rates

# %%
highest_unemplopyment_countries = avg_unemployment_by_country['Country'].head().tolist()
# melt the avg_unemployment DataFrame into three columns
melted = pd.melt(avg_unemployment_by_country, id_vars=['Country'], var_name='Label', value_name='Value')
melted = melted[melted['Country'].isin(highest_unemplopyment_countries)]
# display the resulting DataFrame
melted
# Out:
#           Country                             Label      Value
# 0        Djibouti     Avg.Employment in Industry(%)   5.522972
# 1       Swaziland     Avg.Employment in Industry(%)  24.365639
# 2    South Africa     Avg.Employment in Industry(%)  23.529014
# 3         Namibia     Avg.Employment in Industry(%)  14.562382
# 4     Congo, Rep.     Avg.Employment in Industry(%)  22.927716
# 51       Djibouti  Avg.Employment in Agriculture(%)   3.564415
# 52      Swaziland  Avg.Employment in Agriculture(%)  17.588834
# 53   South Africa  Avg.Employment in Agriculture(%)  19.415858
# 54        Namibia  Avg.Employment in Agriculture(%)  30.387237
# 55    Congo, Rep.  Avg.Employment in Agriculture(%)  39.143200
# 102      Djibouti               Avg.Unemployment(%)  27.673964
# 103     Swaziland               Avg.Unemployment(%)  24.707179
# 104  South Africa               Avg.Unemployment(%)  22.034071
# 105       Namibia               Avg.Unemployment(%)  21.273714
# 106   Congo, Rep.               Avg.Unemployment(%)  20.386393

# %%
# Create a figure with a bar plot of the melted DataFrame
fig = plt.figure(figsize=(12, 6))
sns.barplot(data=melted, x='Country', y='Value', hue='Label')

# Set the title and labels of the plot
plt.title('Distribution of average employment and unemployment rate in 5 countries', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Country', fontsize=14, labelpad=20)
plt.ylabel('Percent', fontsize=14, labelpad=20)

# Adjust the layout of the plot and display the figure
plt.tight_layout()
plt.show()

# %% [markdown]
# Step 03: My observations and thoughts

# %% [markdown]
# - Djibouti has the highest unemployment rate of the five countries, followed by Swaziland, South Africa, Namibia, and the Republic of Congo. The unemployment rate in all five countries decreased from 1995 to 2002, but increased significantly to 2020. However, it decreased slightly in 2021 and fell sharply in 2022.
# - Djibouti is the only country with an employment rate in industry and agriculture that is much lower than its unemployment rate. Swaziland and South Africa have similar employment and unemployment rates. The employment rate is higher than the unemployment rate in all five countries.

# %%
def get_data(df: pd.DataFrame, selected_columns: list) -> pd.DataFrame:
    """Returns a DataFrame containing the selected columns from the input DataFrame."""
    return df[selected_columns]

def group_by(df: pd.DataFrame, key: str, columns: list, method: str) -> pd.DataFrame:
    """Returns a DataFrame grouped by the specified key and aggregated using the specified method."""
    return df.groupby(key)[columns].agg(method).reset_index().\
        sort_values(by=columns, ascending=False).reset_index(drop=True).\
        rename(columns={column: f'Avg.{column}' for column in columns})

def plot_top_values(df: pd.DataFrame, x: str, y: str, top_n: int, ax: plt.Axes = None) -> None:
    """Plots a bar chart of the top `top_n` values in the specified column `y` of the input DataFrame, grouped by the specified column `x`.

    Args:
        df: The DataFrame to plot.
        x: The column to group by.
        y: The column to plot.
        top_n: The number of top values to plot.
        ax: The optional Axes object to plot on.
    """

    colors = ['grey'] * len(df)
    colors[df[y].idxmax()] = 'red'

    sns.barplot(x=x, y=y, data=df.head(top_n), palette=colors, ax=ax)

# %% [markdown]
# ## Make a question 03

# %% [markdown]
# **A possible question is:** What are the global trends in population size and gender composition over time?
#
# **Answering this question will** help us to learn about population growth and gender trends will help us understand how evenly distributed the global population is and how gender composition is changing.
#
# **How we answer this question:** We will collect data on total population by continent and country over time to show population trends.

# %% [markdown]
# ### Pre-Processing

# %%
selected_cols = ['Country', 'Year', 'Total Population', 'Male Population', 'Female Population']
data = df_copy[selected_cols].copy()
data.head()
# Out:
#    Country  Year  Total Population  Male Population  Female Population
# 0  Algeria  2022        44903225.0       22862237.0         22040988.0
# 1  Algeria  2021        44177969.0       22497244.0         21680725.0
# 2  Algeria  2020        43451666.0       22132899.0         21318767.0
# 3  Algeria  2019        42705368.0       21756903.0         20948465.0
# 4  Algeria  2018        41927007.0       21362603.0         20564404.0

# %%
def get_population_data(data, country=None):
    """Returns the population data of the specified country or total if country is None."""
    if country:
        data = data[data['Country'] == country]
    return data.groupby('Year')[['Total Population', 'Male Population', 'Female Population']].sum().reset_index()

def plot_population_data(data, ax):
    """Plots the population data."""
    melted_data = data.melt(id_vars='Year', var_name='Population', value_name='Count')
    sns.lineplot(x='Year', y='Count', hue='Population', data=melted_data, ax=ax)

# %% [markdown]
# ### Analyzing to get answer

# %%
# Get the population data
total_population = get_population_data(data)
algeria_population = get_population_data(data, 'Algeria')

# %%
total_population.head(10)
# Out:
#    Year  Total Population  Male Population  Female Population
# 0  1995       665956879.0      331346584.0        334610295.0
# 1  1996       683174627.0      339796248.0        343378379.0
# 2  1997       700515518.0      348421251.0        352094267.0
# 3  1998       717746662.0      357067120.0        360679542.0
# 4  1999       735181043.0      365791781.0        369389262.0
# 5  2000       753081139.0      374762465.0        378318674.0
# 6  2001       771490802.0      383989278.0        387501524.0
# 7  2002       790446263.0      393503801.0        396942462.0
# 8  2003       809972779.0      403327672.0        406645107.0
# 9  2004       830089936.0      413440390.0        416649546.0

# %%
algeria_population.head(10)
# Out:
#    Year  Total Population  Male Population  Female Population
# 0  1995        28478022.0       14462522.0         14015500.0
# 1  1996        28984634.0       14736488.0         14248146.0
# 2  1997        29476031.0       15025934.0         14450097.0
# 3  1998        29924668.0       15272209.0         14652459.0
# 4  1999        30346083.0       15482799.0         14863284.0
# 5  2000        30774621.0       15698203.0         15076418.0
# 6  2001        31200985.0       15912853.0         15288132.0
# 7  2002        31624696.0       16126874.0         15497822.0
# 8  2003        32055883.0       16346159.0         15709724.0
# 9  2004        32510186.0       16578139.0         15932047.0

# %%
# Create the subplots
fig, ax = plt.subplots(1, 2, figsize=(16, 5))

# Plot the data
plot_population_data(total_population, ax[0])
plot_population_data(algeria_population, ax[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion

# %% [markdown]
# In many African countries, the total female population was higher than the total male population before 2015. After 2015, the female population line crossed the male population line and became equal, or even slightly higher. However, there are some African countries where the total male population is still higher than the female population.

# %% [markdown]
# ## Making a question 04

# %% [markdown]
# **A possible question is:** What is the difference in population rates between males and females in different countries?
#
# **Answering this question will** help us to understand the gender gap in population size.
#
# **How we answer this question:** We will compare the average male population and female population for countries across all years, and calculate the difference rate between them.

# %% [markdown]
# ### Pre-Processing

# %%
selected_cols = ['Country', 'Total Population', 'Male Population', 'Female Population']
data = df_copy[selected_cols].copy()
data.head()
# Out:
#    Country  Total Population  Male Population  Female Population
# 0  Algeria        44903225.0       22862237.0         22040988.0
# 1  Algeria        44177969.0       22497244.0         21680725.0
# 2  Algeria        43451666.0       22132899.0         21318767.0
# 3  Algeria        42705368.0       21756903.0         20948465.0
# 4  Algeria        41927007.0       21362603.0         20564404.0

# %% [markdown]
# ### Analyzing to get answer

# %% [markdown]
# Step 01: Comparing the average male population and female population for countries across all years

# %%
avg_male_population = group_by(data, 'Country', ['Male Population'], 'mean')
avg_female_population = group_by(data, 'Country', ['Female Population'], 'mean')

# %%
avg_female_population.head()
# Out:
#             Country  Avg.Female Population
# 0           Nigeria           7.829816e+07
# 1          Ethiopia           4.346507e+07
# 2  Egypt, Arab Rep.           4.252790e+07
# 3      South Africa           2.676592e+07
# 4          Tanzania           2.282646e+07

# %%
avg_male_population.head()
# Out:
#             Country  Avg.Male Population
# 0           Nigeria         7.950886e+07
# 1          Ethiopia         4.391138e+07
# 2  Egypt, Arab Rep.         4.359680e+07
# 3      South Africa         2.477647e+07
# 4          Tanzania         2.222470e+07

# %%
fig, ax = plt.subplots(1,2, figsize = (18, 6), sharey=True)

plot_top_values(avg_male_population, 'Country', 'Avg.Male Population', 5, ax=ax[0])
plot_top_values(avg_female_population, 'Country', 'Avg.Female Population', 5, ax=ax[1])

# %% [markdown]
# Step 02: Calculating the difference rate between male population and female population

# %%
population_rate = data.groupby('Country')[['Total Population', 'Male Population', 'Female Population']].mean().reset_index()
population_rate['Difference Rate'] = abs(population_rate['Male Population'] - population_rate['Female Population']) / population_rate['Total Population']

# %%
population_rate.head()
# Out:
#         Country  Total Population  Male Population  Female Population  \
# 0       Algeria      3.571866e+07     1.820446e+07       1.751420e+07
# 1        Angola      2.312858e+07     1.139805e+07       1.173053e+07
# 2         Benin      9.271713e+06     4.620473e+06       4.651240e+06
# 3      Botswana      2.055773e+06     1.007011e+06       1.048762e+06
# 4  Burkina Faso      1.581270e+07     7.841559e+06       7.971141e+06
#
#    Difference Rate
# 0         0.019325
# 1         0.014376
# 2         0.003318
# 3         0.020309
# 4         0.008195

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(data=population_rate, x='Difference Rate', bins=20, kde=True, color='grey', ax=ax[0])
plot_top_values(df=population_rate.sort_values(by='Difference Rate', ascending=False).reset_index(drop=True), x='Country', y='Difference Rate', top_n=5, ax=ax[1])

# %% [markdown]
# ### Conclusion

# %% [markdown]
# The five countries with the highest male and female populations in Africa are the same. However, male populations are higher than female populations in all of these countries except for South Africa and Tanzania.
#
# The difference rate between male and female populations in all African countries is almost always less than 0.05, which means that the distribution of males and females in the population is relatively equal. Zimbabwe is the only African country with a difference rate greater than 0.05.

# %% [markdown]
# ## Make a question 05

# %% [markdown]
# **A possible question is:** What is the economic situation of the Africa continent?
#
# **Answering this question will** help us to understand economic statistics and make decisions for the future.
#
# **How we answer this question:** We will calculate the average of all economic statistics for all countries across all years, and analyze the distribution of each statistic by continent and the correlation between them.

# %% [markdown]
# ### Pre-Processing

# %%
from sklearn.preprocessing import StandardScaler

# %%
selected_cols = ['Country', 'GDP in USD', 'National Income per Capita', 'Net income from Abroad', 'Agriculture value added(in USD)']
data = df_copy[selected_cols].copy()
data.head()
# Out:
#    Country    GDP in USD  National Income per Capita  Net income from Abroad  \
# 0  Algeria  1.919129e+11                    2.052086           -1.116459e+09
# 1  Algeria  1.634722e+11                    2.052086           -2.899985e+09
# 2  Algeria  1.457437e+11                   -5.507740           -2.944261e+09
# 3  Algeria  1.717603e+11                   -1.525483           -4.199272e+09
# 4  Algeria  1.749109e+11                   -0.533998           -4.403811e+09
#
#    Agriculture value added(in USD)
# 0                     2.184752e+10
# 1                     1.990395e+10
# 2                     2.008932e+10
# 3                     2.118960e+10
# 4                     2.076927e+10

# %%
def plot_histograms(data, columns, bins=20, color='grey'):
    fig, ax = plt.subplots(2, 2, figsize=(16, 8))

    for i, column in enumerate(columns):
        sns.histplot(data=data, x=column, bins=bins, kde=True, color=color, ax=ax[i//2, i%2])

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Analyzing to get answer

# %% [markdown]
# Step 01: Calculating the average of all economic statistics for all countries across all years

# %%
avg_data = data.groupby('Country')[['GDP in USD', 'National Income per Capita', 'Net income from Abroad', 'Agriculture value added(in USD)']].mean().reset_index()

# %%
avg_data.head()
# Out:
#         Country    GDP in USD  National Income per Capita  \
# 0       Algeria  1.269419e+11                    2.717375
# 1        Angola  5.657612e+10                    2.733394
# 2         Benin  8.915341e+09                    2.554655
# 3      Botswana  1.118704e+10                    2.942608
# 4  Burkina Faso  9.369221e+09                    3.008860
#
#    Net income from Abroad  Agriculture value added(in USD)
# 0           -2.725553e+09                     1.284619e+10
# 1           -5.003080e+09                     4.341275e+09
# 2           -6.099780e+07                     2.407978e+09
# 3           -5.045860e+08                     2.437690e+08
# 4           -3.169519e+08                     2.116837e+09

# %% [markdown]
# Step 02: Analyzing the distribution of each statistic by continent and the correlation between them.

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(avg_data[['GDP in USD', 'National Income per Capita', 'Net income from Abroad', 'Agriculture value added(in USD)']])
scaled_data = pd.DataFrame(scaled_data, columns=['GDP in USD', 'National Income per Capita', 'Net income from Abroad', 'Agriculture value added(in USD)'])

# %%
scaled_data.head()
# Out:
#    GDP in USD  National Income per Capita  Net income from Abroad  \
# 0    1.510318                    0.124042               -0.748573
# 1    0.382290                    0.127028               -1.808110
# 2   -0.381757                    0.093703                0.491015
# 3   -0.345339                    0.166036                0.284652
# 4   -0.374480                    0.178389                0.371942
#
#    Agriculture value added(in USD)
# 0                         0.809640
# 1                        -0.065278
# 2                        -0.264161
# 3                        -0.486797
# 4                        -0.294111

# %%
# Define the columns to plot
columns = ['GDP in USD', 'National Income per Capita', 'Net income from Abroad', 'Agriculture value added(in USD)']

# Call the function
plot_histograms(scaled_data, columns)

# %%
# Create a heatmap of the correlation coefficients between the attributes
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(scaled_data.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# ### Conclusion

# %% [markdown]
# There are two left-skewed distributions: GDP in the USA and agricultural value added (in USD). There is one right-skewed distribution: net income from abroad. There is a symmetric distribution: national income per capita.
#
# GDP in the USA and net income from abroad have a higher correlation than other pairs of variables. The correlation coefficient between these two variables is positive. Agricultural value added (in USD) has a negative correlation with all other variables.

# %% [markdown]
# ## Making a question 06

# %% [markdown]
# **A possible question is:** What is the status of education in all African countries?
#
# **Answering this question will** help us to understand the school enrollment rates at all levels and make decisions for future improvement.
#
# **How we answer this question:** We will calculate the average school enrollment rate at all levels for all African countries across all years and analyze the correlation between primary enrollment and primary completion rate.

# %% [markdown]
# ### Pre-Processing

# %%
selected_cols = ['Country', 'School enrollment, primary', 'School enrollment, tertiary', 'Primary completion rate']
data = get_data(df_copy, selected_cols)
data.head()
# Out:
#    Country  School enrollment, primary  School enrollment, tertiary  \
# 0  Algeria                   97.409735                    10.196134
# 1  Algeria                   97.409735                    53.741741
# 2  Algeria                  111.281151                    52.498619
# 3  Algeria                  108.845848                    52.619942
# 4  Algeria                  109.882820                    51.365669
#
#    Primary completion rate
# 0                67.268794
# 1                67.268794
# 2               103.663528
# 3               101.364632
# 4               105.143959

# %% [markdown]
# ### Analyzing to get answer

# %% [markdown]
# Step 01: Calculating the average school enrollment rate at all levels for all African countries across all years

# %%
avg_enrollment_primary = group_by(data, 'Country', ['School enrollment, primary'], 'mean')
avg_enrollment_tertiary = group_by(data, 'Country', ['School enrollment, tertiary'], 'mean')

# %%
avg_enrollment_primary.head()
# Out:
#       Country  Avg.School enrollment, primary
# 0      Malawi                      132.755930
# 1      Rwanda                      127.845799
# 2  Madagascar                      123.262609
# 3        Togo                      119.367457
# 4     Namibia                      117.640080

# %%
avg_enrollment_tertiary.head()
# Out:
#             Country  Avg.School enrollment, tertiary
# 0           Tunisia                        26.863156
# 1           Algeria                        26.846871
# 2         Mauritius                        25.040505
# 3  Egypt, Arab Rep.                        24.306490
# 4           Morocco                        18.920886

# %%
# Plot the top 5 countries with the highest renewable energy consumption
fig, ax = plt.subplots(1, 2, figsize=(20, 8), sharey=True)

ax[0].set_title('Avg.School enrollment, primary', fontsize=18, fontweight='bold', pad=30)
ax[0].set_xlabel('Avg.School enrollment, primary', fontsize=16, labelpad=20)
ax[0].set_ylabel('Country', fontsize=16, labelpad=20)

plot_top_values(avg_enrollment_primary, x='Country', y='Avg.School enrollment, primary', top_n=5, ax=ax[0])

# Plot the top 5 countries with the highest GDP
ax[1].set_title('Avg.School enrollment, tertiary', fontsize=18, fontweight='bold', pad=30)
ax[1].set_xlabel('Avg.School enrollment, tertiary', fontsize=16, labelpad=20)
ax[1].set_ylabel('Country', fontsize=16, labelpad=20)

plot_top_values(avg_enrollment_tertiary,  x='Country', y='Avg.School enrollment, tertiary', top_n=5, ax=ax[1])

# Add a suptitle to the figure
plt.suptitle('Top 5 countries with the highest feature', fontsize=20, fontweight='bold', y=1.05)

# Tighten the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Step 02: Analyzing the correlation between primary enrollment and primary completion rate.

# %%
# Create a DataFrame with the two attributes
df = data[['School enrollment, primary', 'Primary completion rate']].dropna()

# Calculate the correlation between the two attributes
correlation = df.corr().iloc[0, 1]

# Print the correlation coefficient
print('Correlation coefficient:', correlation)

# Create a scatter plot with a regression line
sns.regplot(x='School enrollment, primary', y='Primary completion rate', data=df, color='blue', line_kws={'color':'red'})

# Label the axes and title
plt.xlabel('School enrollment, primary (%)')
plt.ylabel('Primary completion rate (%)')
plt.title('School enrollment, primary vs. primary completion rate')

# Show the plot
plt.show()
# Out:
# Correlation coefficient: 0.5248102581861827

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Primary school enrollment is three times higher than tertiary school enrollment. Additionally, the primary school completion rate has a low correlation with primary school enrollment. This indicates that many children enroll in primary school, but only half of them complete their primary education.

# %% [markdown]
# ## Make a question 07

# %% [markdown]
# **A possible question is:** What is the average resource consumption rate across all sectors in all African countries?
#
# **Answering this question will** help us to understand the current state of resource consumption in Africa and make informed decisions for future improvement.
#
# **How we answer this question:** We will calculate the average resource consumption rate across all sectors for all African countries across all years.

# %% [markdown]
# ### Pre-Processing

# %%
selected_cols = ['Country', 'Electric Power Consumption(kWH per capita)', 'Renewable Energy Consumption (%)', 'Fossil Fuel Consumption (%)']
data = df_copy[selected_cols]
data.head()
# Out:
#    Country  Electric Power Consumption(kWH per capita)  \
# 0  Algeria                                  712.608182
# 1  Algeria                                  712.608182
# 2  Algeria                                  712.608182
# 3  Algeria                                  712.608182
# 4  Algeria                                  712.608182
#
#    Renewable Energy Consumption (%)  Fossil Fuel Consumption (%)
# 0                         60.381415                    41.345309
# 1                         60.381415                    41.345309
# 2                          0.150000                    41.345309
# 3                          0.160000                    41.345309
# 4                          0.190000                    41.345309

# %% [markdown]
# ### Analyzing to get answer

# %%
# Group by 'Country' and calculate the mean and sum
avg_electric_power_consumption = data.groupby('Country')['Electric Power Consumption(kWH per capita)'].mean().reset_index().rename(columns={'Electric Power Consumption(kWH per capita)': 'Avg.Electric Power Consumption(kWH per capita)'})
sum_electric_power_consumption = data.groupby('Country')['Electric Power Consumption(kWH per capita)'].sum().reset_index().rename(columns={'Electric Power Consumption(kWH per capita)': 'Sum.Electric Power Consumption(kWH per capita)'})

# Calculate the percent
percent = [i / j * 100 for i, j in zip(avg_electric_power_consumption['Avg.Electric Power Consumption(kWH per capita)'].tolist(), sum_electric_power_consumption['Sum.Electric Power Consumption(kWH per capita)'].tolist())]

# Create a DataFrame to hold the results
result = pd.DataFrame({
    'Country': avg_electric_power_consumption['Country'],
    'Avg Electric Power Consumption': avg_electric_power_consumption['Avg.Electric Power Consumption(kWH per capita)'],
    'Sum Electric Power Consumption': sum_electric_power_consumption['Sum.Electric Power Consumption(kWH per capita)'],
    'Percent': percent
}).sort_values(by='Percent', ascending=False).reset_index(drop=True)

# Display the first 10 rows
result.head(10)
# Out:
#                  Country  Avg Electric Power Consumption  \
# 0               Zimbabwe                      760.917749
# 1                  Benin                      253.625442
# 2                  Kenya                      300.570024
# 3              Mauritius                     1361.896734
# 4                Namibia                     1177.234897
# 5                  Niger                      351.636819
# 6  Sao Tome and Principe                      712.608182
# 7                   Mali                      712.608182
# 8             Mauritania                      712.608182
# 9                Morocco                      660.799718
#
#    Sum Electric Power Consumption   Percent
# 0                    21305.696972  3.571429
# 1                     7101.512390  3.571429
# 2                     8415.960670  3.571429
# 3                    38133.108558  3.571429
# 4                    32962.577114  3.571429
# 5                     9845.830927  3.571429
# 6                    19953.029109  3.571429
# 7                    19953.029109  3.571429
# 8                    19953.029109  3.571429
# 9                    18502.392106  3.571429

# %%
avg_renewable_energy_consumption = group_by(data, 'Country', ['Renewable Energy Consumption (%)'], 'mean')
avg_renewable_energy_consumption.head(10)
# Out:
#                     Country  Avg.Renewable Energy Consumption (%)
# 0                    Uganda                             92.489693
# 1                   Somalia                             92.357193
# 2                  Ethiopia                             91.086172
# 3                   Burundi                             90.849693
# 4  Central African Republic                             90.490765
# 5                   Liberia                             89.054693
# 6                  Tanzania                             87.550101
# 7             Guinea-Bissau                             87.224693
# 8                    Rwanda                             86.675051
# 9                Mozambique                             85.756887

# %%
avg_fossil_fuel_consumption = group_by(data, 'Country', ['Fossil Fuel Consumption (%)'], 'mean')
avg_fossil_fuel_consumption.head(10)
# Out:
#             Country  Avg.Fossil Fuel Consumption (%)
# 0           Algeria                        83.096983
# 1             Libya                        82.620944
# 2  Egypt, Arab Rep.                        80.156158
# 3           Tunisia                        74.091404
# 4           Morocco                        73.686352
# 5      South Africa                        73.455267
# 6         Mauritius                        66.138795
# 7          Botswana                        58.359208
# 8           Namibia                        57.863663
# 9           Senegal                        47.701697

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 8), sharey=True)

plot_top_values(result, x='Country', y='Percent', top_n=5, ax=ax[0])
plot_top_values(avg_renewable_energy_consumption, x='Country', y='Avg.Renewable Energy Consumption (%)', top_n=5, ax=ax[1])
plot_top_values(avg_fossil_fuel_consumption, x='Country', y='Avg.Fossil Fuel Consumption (%)', top_n=5, ax=ax[2])

ax[0].set_title('Average of Electric Power Consumption(%)', fontsize=18, fontweight='bold', pad=30)
ax[1].set_title('Average of Renewable Energy Consumption (%)', fontsize=18, fontweight='bold', pad=30)
ax[2].set_title('Average of Fossil Fuel Consumption (%)', fontsize=18, fontweight='bold', pad=30)

plt.suptitle('Top 5 countries with the highest feature', fontsize=20, fontweight='bold', y=1.05)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Renewable energy consumption is higher than fossil fuel consumption in all African countries.

# %% [markdown]
# ## Make a question 08

# %% [markdown]
# **A possible question is:** What is the employment rate across all sectors in all African countries, and how is it distributed across industry, agriculture, and gender?
#
# **Answering this question will** help us to understand the current state of employment and make informed decisions for future improvement.
#
# **How we answer this question:** We will show the distribution of employment rate by sector and gender for all African countries.

# %% [markdown]
# ### Pre-Processing

# %%
selected_cols = ['Country', 'Employment in Industry(%)', 'Employment in Agriculture(%)', 'Female Employment in Agriculture(%)', 'Female Employment in Industry(%)', 'Unemployment(%)']
data = df_copy[selected_cols].copy()
data.head()
# Out:
#    Country  Employment in Industry(%)  Employment in Agriculture(%)  \
# 0  Algeria                   13.74374                     48.164092
# 1  Algeria                   31.03555                     10.323790
# 2  Algeria                   30.49272                     10.524500
# 3  Algeria                   30.46512                      9.940742
# 4  Algeria                   30.68305                     10.007310
#
#    Female Employment in Agriculture(%)  Female Employment in Industry(%)  \
# 0                            49.723269                         10.118534
# 1                             3.929019                         23.940450
# 2                             3.867479                         24.429170
# 3                             3.754027                         23.812240
# 4                             3.807302                         24.043400
#
#    Unemployment(%)
# 0           11.550
# 1           11.747
# 2           12.248
# 3           10.495
# 4           10.416

# %% [markdown]
# ### Analyzing to get answer

# %%
data.describe()
# Out:
#        Employment in Industry(%)  Employment in Agriculture(%)  \
# count                1428.000000                   1428.000000
# mean                   13.743740                     48.164092
# std                     7.674594                     21.623268
# min                     2.195539                      1.184986
# 25%                     7.575027                     32.196838
# 50%                    12.826850                     48.164092
# 75%                    18.248188                     66.358423
# max                    39.834960                     92.591690
#
#        Female Employment in Agriculture(%)  Female Employment in Industry(%)  \
# count                          1428.000000                       1428.000000
# mean                             49.723269                         10.118534
# std                              24.430893                          8.170177
# min                               0.913054                          0.206030
# 25%                              29.076730                          3.919370
# 50%                              49.723269                          8.354249
# 75%                              70.288610                         13.668938
# max                              96.987240                         43.624750
#
#        Unemployment(%)
# count      1428.000000
# mean          9.222008
# std           7.262447
# min           0.320000
# 25%           3.462750
# 50%           6.304500
# 75%          14.364500
# max          31.840000

# %%
def hist_plots(df, columns, bins=20, color='grey'):
    fig, ax = plt.subplots(2, 3, figsize=(20, 10))

    for i, column in enumerate(columns):
        sns.histplot(data=df, x=column, bins=bins, kde=True, color=color, ax=ax[i//3, i%3])
        ax[i//3, i%3].set_xlabel(column, fontsize=14, labelpad=20)
        ax[i//3, i%3].set_ylabel('Count', fontsize=14, labelpad=20)

    plt.tight_layout()
    plt.show()
    
hist_plots(data, columns=data.columns[1:].to_list())

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Employment in agriculture is likely to be higher than employment in industry in African countries, with the percentage of workers employed in agriculture ranging from 20% to 60% and the percentage of workers employed in industry ranging from 5% to 15%.
#
# Additionally, women are more likely to be employed in agriculture than in industry, with the percentage of female workers employed in agriculture ranging from 40% to 80%.
#
# The unemployment rate in all African countries is likely to be between 0% and 5%.
